# %%
import numpy as np
import pandas as pd
import re

# %%
raw_data = pd.read_excel('Bibliometrix-Export-File-2021-11-17.xlsx', sheet_name='Sheet1')
selected_columns = ['AF',
                 'C1',
                 'DT',
                 'LA',
                 'PY',
                 'TI'
                ]
raw_data_copy = raw_data[selected_columns].copy()
#Authors_Full_Name_aux = raw_data_copy['AF'].str.replace(',', '_').str.replace(' ', '_').str.replace(';',',')
lst_col = 'AF'
Authors_Full_Name_aux = raw_data_copy.assign(**{lst_col:raw_data_copy[lst_col].str.replace(',','-').str.replace(' ','_').str.split(';')})
Authors_Full_Name = Authors_Full_Name_aux.explode('AF')
Authors_Full_Name.AF = Authors_Full_Name['AF'].str.replace('-',',').str.replace('_',' ')
#Authors_Full_Name.to_excel('AF_split.xlsx')
#print(Authors_Full_Name)

# %%
raw_data = pd.read_excel('Bibliometrix-Export-File-2021-11-17.xlsx', sheet_name='Sheet1')
selected_columns = ['C1','TI']
raw_data_copy = raw_data[selected_columns].copy()
lst_col = 'C1'
Affiliation_aux = raw_data_copy.assign(**{lst_col:raw_data_copy[lst_col].str.replace(',','-').str.replace(' ','_').str.split(';')})
Affiliation_country.to_excel('Affiliation_country.xlsx')
#print(Affiliation_country)

# %%
Country_df = pd.read_excel('Affiliation_country.xlsx')
Country_df.C1 = Country_df['C1'].str.split(',')
for i in range (Country_df['C1'].size):
    Country_df['C1'].iloc[i] = Country_df['C1'].iloc[i][-1]
Country_df.to_excel('Country.xlsx')
print(Country_df)
# Out:
#              C1                                                 TI
# 0       BRAZIL.  FRBR AND RDA BASED METADATA APPLICATIONS IN DI...
# 1     COLOMBIA.  EYE TRACKING AND USABILITY IN DIGITAL INFORMAT...
# 2       BRAZIL.  EYE TRACKING AND USABILITY IN DIGITAL INFORMAT...
# 3       BRAZIL.  METHODOLOGICAL CHOICES FOR RESEARCH IN INFORMA...
# 4       BRAZIL.  METHODOLOGICAL CHOICES FOR RESEARCH IN INFORMA...
# ..          ...                                                ...
# 426     BRAZIL.  THE SEARCH FOR INFORMATION ON THE INTERNET: A ...
# 427     BRAZIL.  THE SEARCH FOR INFORMATION ON THE INTERNET: A ...
# 428     BRAZIL.  THE THEORETICAL APPROACH OF LENA VANIA RIBEIRO...
# 429     BRAZIL.  IMPROVEMENT OF STRATEGISTS AND NOVICE DECISION...
# 430     BRAZIL.  IMPROVEMENT OF STRATEGISTS AND NOVICE DECISION...
#
# [431 rows x 2 columns]

# %%
selected_columns = ['AU_UN','TI']
raw_data_copy = raw_data[selected_columns].copy()
lst_col = 'AU_UN'
Affiliation_aux = raw_data_copy.assign(**{lst_col:raw_data_copy[lst_col].str.replace(',','-').str.replace(' ','_').str.split(';')})
Affiliation_university = Affiliation_aux.explode('AU_UN')
Affiliation_university.AU_UN = Affiliation_university['AU_UN'].str.replace('-',',').str.replace('_',' ').str.strip()
Affiliation_university.to_excel('Affiliation_university.xlsx')
#print(Affiliation_university)

# %%
Countries_List = pd.read_excel('Countries.xls', sheet_name='Data')['Country_Name'].tolist()
Countries_List = [x.upper() for x in Countries_List]
lst_col = 'C1'
Author_C1 = raw_data_copy.assign(**{lst_col:raw_data_copy[lst_col].str.replace(';','').str.replace('.','').str.replace(' ','').str.split(';')})
country_aux = (Author_C1['C1'].iloc[0])[0].split(',')[-1]
if country_aux in set(Countries_List):
    print('ok')
print((Author_C1['C1'].iloc[0])[0].split(',')[-1])
# Out:
# BRAZIL
# ok
# BRAZIL

# %%
Author_C1_aux = Author_C1['C1']
for i in range (Author_C1_aux.size):
    country_aux = []
    list_aux = (Author_C1_aux.iloc[i])[0].split(',')
    for j in range (len(list_aux)):
        if list_aux[j] in set(Countries_List):
            country_aux.append(list_aux[j])
    print (country_aux)
# Out:
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['MEXICO']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['FRANCE']
# ['BRAZIL']
# ['BRAZIL']
# ['PORTUGAL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# []
# ['BRAZIL']
# ['ECUADOR']
# ['BRAZIL']
# ['SPAIN']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['CUBA']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['COLOMBIA']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['CUBA']
# ['BRAZIL']
# ['BRAZIL']
# ['URUGUAY']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['MEXICO']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['CHILE']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['URUGUAY']
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['MEXICO']
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['SPAIN']
# ['COLOMBIA']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['SPAIN']
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['SPAIN']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['MEXICO']
# ['SPAIN']
# ['CANADA']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['SPAIN']
# ['CUBA']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# []
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['CHILE']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['PERU']
# ['BRAZIL']
# ['BRAZIL']
# ['PORTUGAL']
# ['CHILE']
# []
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['PORTUGAL']
# ['COLOMBIA']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['SPAIN']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# []
# ['BRAZIL']
# ['BRAZIL']
# ['HUNGARY']
# ['CUBA']
# ['CUBA']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']
# ['BRAZIL']

# %%
raw_data_df = pd.read_excel('Author_Timeline2.xlsx')

# %%
selected_columns = ['TI', "Article_Timeline"]
Article_Timeline_df = raw_data_df[selected_columns].copy()

# %%
timeline = Article_Timeline_df['Article_Timeline'].iloc[0].split(',')[1]
re.sub(r'\\', '', timeline)
print (timeline.replace('xa0', ' '))
# Out:
#  'Recibido07\ Jul\ 2015\n\nRevisado11\ Nov\ 2015\n\nAcepto17\ Dic\ 2015']
